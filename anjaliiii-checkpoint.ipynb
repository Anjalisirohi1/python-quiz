# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde

# %%
df = pd.read_csv(r"C:\Users\ashis\insurance_data.csv")

# %%
df_insurance=df.copy()

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
##Numerical feature - index, PatientID, age, bmi, bloodpressure, claim

##Categorical feature - gender, diabetic, children, smoker, region

# %%
df_insurance = df.copy()

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df_insurance.shape
# Out:
# (1340, 11)

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df_insurance.tail()
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 1335    Yes  northwest  55135.40
# 1336    Yes  northeast  58571.07
# 1337    Yes  northwest  60021.40
# 1338    Yes  southeast  62592.87
# 1339    Yes  southeast  63770.43

# %%
df_insurance.sample(5)
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 282     282        283  48.0  female  33.3            100      Yes         1
# 1180   1180       1181  39.0    male  29.8            110       No         3
# 151     151        152  26.0    male  33.7             99       No         0
# 127     127        128  49.0    male  28.9             81       No         0
# 550     550        551  28.0  female  25.0             97       No         1
#
#      smoker     region     claim
# 282      No  southeast   4151.03
# 1180    Yes  northeast  30184.94
# 151      No  southeast   2498.41
# 127      No  northwest   2250.84
# 550      No  southwest   7623.52

# %%
df_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1340 non-null   int64
#  1   PatientID      1340 non-null   int64
#  2   age            1335 non-null   float64
#  3   gender         1340 non-null   object
#  4   bmi            1340 non-null   float64
#  5   bloodpressure  1340 non-null   int64
#  6   diabetic       1340 non-null   object
#  7   children       1340 non-null   int64
#  8   smoker         1340 non-null   object
#  9   region         1337 non-null   object
#  10  claim          1340 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 115.3+ KB

# %%
df_insurance.isnull()
# Out:
#       index  PatientID    age  gender    bmi  bloodpressure  diabetic  \
# 0     False      False  False   False  False          False     False
# 1     False      False  False   False  False          False     False
# 2     False      False   True   False  False          False     False
# 3     False      False   True   False  False          False     False
# 4     False      False   True   False  False          False     False
# ...     ...        ...    ...     ...    ...            ...       ...
# 1335  False      False  False   False  False          False     False
# 1336  False      False  False   False  False          False     False
# 1337  False      False  False   False  False          False     False
# 1338  False      False  False   False  False          False     False
# 1339  False      False  False   False  False          False     False
#
#       children  smoker  region  claim
# 0        False   False   False  False
# 1        False   False   False  False
# ...

# %%
df_insurance.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
df_insurance.describe()
# Out:
#              index    PatientID          age          bmi  bloodpressure  \
# count  1340.000000  1340.000000  1335.000000  1340.000000    1340.000000
# mean    669.500000   670.500000    38.078652    30.668955      94.157463
# std     386.968991   386.968991    11.102924     6.106735      11.434712
# min       0.000000     1.000000    18.000000    16.000000      80.000000
# 25%     334.750000   335.750000    29.000000    26.275000      86.000000
# 50%     669.500000   670.500000    38.000000    30.400000      92.000000
# 75%    1004.250000  1005.250000    47.000000    34.700000      99.000000
# max    1339.000000  1340.000000    60.000000    53.100000     140.000000
#
#           children         claim
# count  1340.000000   1340.000000
# mean      1.093284  13252.745642
# std       1.205334  12109.609288
# min       0.000000   1121.870000
# 25%       0.000000   4719.685000
# 50%       1.000000   9369.615000
# 75%       2.000000  16604.305000
# max       5.000000  63770.430000

# %%
df_insurance.describe().sum()
# Out:
# index              5743.968991
# PatientID          5749.968991
# age                1576.181576
# bmi                1537.250690
# bloodpressure      1942.592174
# children           1350.298618
# claim            122288.259930
# dtype: float64

# %%
df_insurance.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1335    False
# 1336    False
# 1337    False
# 1338    False
# 1339    False
# Length: 1340, dtype: bool

# %%
df_insurance.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_insurance.corr(numeric_only=True)
# Out:
#                   index  PatientID       age       bmi  bloodpressure  \
# index          1.000000   1.000000 -0.007492  0.115129       0.450602
# PatientID      1.000000   1.000000 -0.007492  0.115129       0.450602
# age           -0.007492  -0.007492  1.000000 -0.041955      -0.060325
# bmi            0.115129   0.115129 -0.041955  1.000000       0.143544
# bloodpressure  0.450602   0.450602 -0.060325  0.143544       1.000000
# children       0.128104   0.128104 -0.025547  0.012092      -0.031682
# claim          0.879268   0.879268 -0.027909  0.197401       0.531341
#
#                children     claim
# index          0.128104  0.879268
# PatientID      0.128104  0.879268
# age           -0.025547 -0.027909
# bmi            0.012092  0.197401
# bloodpressure -0.031682  0.531341
# children       1.000000  0.069233
# claim          0.069233  1.000000

# %%
df_insurance.corr(numeric_only=True)['index']
# Out:
# index            1.000000
# PatientID        1.000000
# age             -0.007492
# bmi              0.115129
# bloodpressure    0.450602
# children         0.128104
# claim            0.879268
# Name: index, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['PatientID']
# Out:
# index            1.000000
# PatientID        1.000000
# age             -0.007492
# bmi              0.115129
# bloodpressure    0.450602
# children         0.128104
# claim            0.879268
# Name: PatientID, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['age']
# Out:
# index           -0.007492
# PatientID       -0.007492
# age              1.000000
# bmi             -0.041955
# bloodpressure   -0.060325
# children        -0.025547
# claim           -0.027909
# Name: age, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['bmi']
# Out:
# index            0.115129
# PatientID        0.115129
# age             -0.041955
# bmi              1.000000
# bloodpressure    0.143544
# children         0.012092
# claim            0.197401
# Name: bmi, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['bloodpressure']
# Out:
# index            0.450602
# PatientID        0.450602
# age             -0.060325
# bmi              0.143544
# bloodpressure    1.000000
# children        -0.031682
# claim            0.531341
# Name: bloodpressure, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['children']
# Out:
# index            0.128104
# PatientID        0.128104
# age             -0.025547
# bmi              0.012092
# bloodpressure   -0.031682
# children         1.000000
# claim            0.069233
# Name: children, dtype: float64

# %%
df_insurance.corr(numeric_only=True)['claim']
# Out:
# index            0.879268
# PatientID        0.879268
# age             -0.027909
# bmi              0.197401
# bloodpressure    0.531341
# children         0.069233
# claim            1.000000
# Name: claim, dtype: float64

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
#          AGE
#     conclusions
#     -there are 5 missing values
#     -the average is around 39
#     -age is normally(almost) distributed that is skewness is close to zero
#     -there are no outliers

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df_insurance['age'].isnull().sum()
# Out:
# np.int64(5)

# %%
df_insurance['age'].isnull().sum()/len(df_insurance['age'])
# Out:
# np.float64(0.0037313432835820895)

# %%
df_insurance['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
df_insurance['age'].fillna(df_insurance['age'].mean())
# Out:
# 0       39.000000
# 1       24.000000
# 2       38.078652
# 3       38.078652
# 4       38.078652
#           ...
# 1335    44.000000
# 1336    59.000000
# 1337    30.000000
# 1338    37.000000
# 1339    30.000000
# Name: age, Length: 1340, dtype: float64

# %%
df_insurance
# Out:
#       index  PatientID        age  gender   bmi  bloodpressure diabetic  \
# 0         0          1  39.000000    male  23.2             91      Yes
# 1         1          2  24.000000    male  30.1             87       No
# 2         2          3  38.078652    male  33.3             82      Yes
# 3         3          4  38.078652    male  33.7             80       No
# 4         4          5  38.078652    male  34.1            100       No
# ...     ...        ...        ...     ...   ...            ...      ...
# 1335   1335       1336  44.000000  female  35.5             88      Yes
# 1336   1336       1337  59.000000  female  38.1            120       No
# 1337   1337       1338  30.000000    male  34.5             91      Yes
# 1338   1338       1339  37.000000    male  30.4            106       No
# 1339   1339       1340  30.000000  female  47.4            101       No
#
#       children smoker     region     claim  claim_binary
# ...

# %%
df_insurance.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# claim_binary     0
# dtype: int64

# %%
df_insurance['age'].plot(kind='hist',bins=25,linewidth=1,edgecolor='black',color='yellow')
plt.xlabel("Age")
plt.title('Age Distribution',fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
df_insurance['age'].plot(kind='kde',color='blue')
plt.xlabel('Age')
plt.show()

# %%
df_insurance['age'].skew()
# Out:
# np.float64(0.11361133741072633)

# %%
df_insurance['age'].plot(kind='box')
plt.show()

# %% [markdown]
#         BMI
#     conclusions
#     -there are no missing values
#     -skewness is close to zero so it is normally distributed
#     -Outliers are on the higher side
#     -16 people have severe obesity that is above 46
#     -

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df_insurance['bmi'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
df_insurance['bmi'].plot(kind='hist',bins=25,linewidth=1,edgecolor='black',color='brown')
plt.xlabel("BMI")
plt.ylabel('Num of persons')
plt.title('BMI Distribution',fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
df_insurance['bmi'].plot(kind='kde',color='purple')
plt.xlabel('BMI')
plt.show()

# %%
df_insurance['bmi'].skew()
# Out:
# np.float64(0.28597245020808587)

# %%
df_insurance['bmi'].plot(kind='box')
plt.show()

# %%
df_insurance[df_insurance['bmi'] > 46]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 9         9         10  30.0    male  53.1             97       No         0
# 141     141        142  46.0    male  50.4             89      Yes         1
# 190     190        191  28.0    male  46.5             94       No         1
# 331     331        332  43.0    male  46.5             83      Yes         2
# 464     464        465  20.0    male  46.5             89       No         3
# 579     579        580  25.0    male  47.5             84      Yes         1
# 675     675        676  49.0  female  48.1             81      Yes         2
# 682     682        683  27.0  female  46.1            106       No         1
# 696     696        697  49.0    male  47.7             88       No         1
# 802     802        803  42.0    male  49.1            109      Yes         0
# 814     814        815  57.0  female  46.7            101      Yes         2
# ...

# %%
(df_insurance['bmi'] > 46).sum()
# Out:
# np.int64(16)

# %% [markdown]
#     BLOOD PRESSURE
#     conclusions
#     -there are no missing values
#     -average BP is 95
#     -high positive skewness
#     -there are outliers on the higher side
#     -around 62 people have BP above 119, indicating high/elevated blood pressure
#     -there are more people with low BP than people with high BP

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df_insurance['bloodpressure'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
df_insurance['bloodpressure'].plot(kind='hist',bins=25,linewidth=1,edgecolor='black',color='pink')
plt.xlabel("Blood pressure")
plt.title('Blood Pressure Distribution',fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
df_insurance['bloodpressure'].plot(kind='kde',color='purple')
plt.ylabel('Blood pressure')
plt.show()

# %%
df_insurance['bloodpressure'].skew()
# Out:
# np.float64(1.4835342102293079)

# %%
df_insurance['bloodpressure'].plot(kind='box')
plt.show()

# %%
df[df['bloodpressure']>118]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1147   1147       1148  29.0  female  32.7            128      Yes         2
# 1150   1150       1151  55.0  female  27.1            135       No         1
# 1152   1152       1153  38.0  female  35.9            128       No         1
# 1153   1153       1154  43.0    male  36.8            126       No         2
# 1154   1154       1155  31.0    male  23.8            126      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1325   1325       1326  52.0  female  36.4            133      Yes         1
# 1332   1332       1333  26.0    male  37.0            120       No         2
# 1333   1333       1334  44.0    male  36.4            127       No         1
# 1334   1334       1335  43.0    male  32.8            125       No         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
#
#      smoker     region     claim
# ...

# %%
(df_insurance['bloodpressure']>118).sum()
# Out:
# np.int64(62)

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#     CLAIM
#     conclusions
#     -there are no missing values
#     -average claim is 13252.7256
#     -highly positive skewness
#     -outliers are present on the higher side
#     -around 155 people have claim above 32000

# %%
df_insurance['claim'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
df_insurance['claim'].plot(kind='hist',bins=25,linewidth=1,edgecolor='black',color='seagreen')
plt.xlabel("Amount of claim")

plt.title('Claim Distribution',fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
df_insurance['claim'].plot(kind='kde',color='blue')
plt.xlabel('Claim')
plt.show()

# %%
df_insurance['claim'].skew()
# Out:
# np.float64(1.5167468509489237)

# %%
df_insurance['claim'].plot(kind='box')
plt.show()

# %%
df_insurance[df_insurance['claim'] > 40000]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1261   1261       1262  40.0  female  32.8            107      Yes         2
# 1262   1262       1263  30.0    male  35.3             89       No         2
# 1263   1263       1264  50.0    male  34.1             86       No         4
# 1264   1264       1265  21.0    male  35.8            116       No         1
# 1265   1265       1266  54.0  female  38.4             85      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
(df_insurance['claim'] > 32000).sum()
# Out:
# np.int64(155)

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#         GENDER
#         conclusions
#         -there are 678 males and 662 females,sex ratio is balanced
#         -there are no missing values

# %%
df_insurance['gender'].value_counts()
# Out:
# gender
# male      678
# female    662
# Name: count, dtype: int64

# %%
df_insurance['gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['gender'].value_counts().plot(kind = 'bar',linewidth=1,edgecolor='black',color=['red','purple'])
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender distribution",fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
pie_colors = ['blue','magenta']
df_insurance['gender'].value_counts().plot(kind='pie',autopct= '%.2f%%',colors=pie_colors,shadow=True)
plt.legend()
plt.show()

# %%
df_insurance['gender'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#           DIABETIC
#         conclusions
#        -approx half of the patients are diabetic
#        -there are no missing values

# %%
df_insurance['diabetic'].value_counts()
# Out:
# diabetic
# No     698
# Yes    642
# Name: count, dtype: int64

# %%
df_insurance['gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['diabetic'].value_counts().plot(kind = 'bar',linewidth=1,edgecolor='black',color=['green','orange'])
plt.xlabel("Diabetic")
plt.ylabel('Frequency')
plt.title("Diabetes Status",fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
pie_colors = ['lightskyblue','lime']
df_insurance['diabetic'].value_counts().plot(kind='pie',autopct= '%.2f%%',colors=pie_colors,shadow=True)
plt.legend()
plt.show()

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#             CHILDREN
#             conclusions
#             -half of the patients (43%) do not have children
#             -there are no missing values

# %%
df_insurance['children'].value_counts()
# Out:
# children
# 0    576
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df_insurance['children'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['children'].value_counts().plot(kind = 'bar',linewidth=1,edgecolor='black',color=['green','orange','darkblue','brown','red','orchid'])
plt.xlabel("Number of children")
plt.ylabel('Number of patients')
plt.title("Children count",fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
pie_colors = ['lightskyblue','pink','green','orange','darkblue','brown','red','orchid']
explode= [0.1,0,0,0,0,0]
df_insurance['children'].value_counts().plot(kind='pie',autopct= '%.2f%%',explode=explode,colors=pie_colors,shadow=True)
plt.legend()
plt.show()

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#             SMOKER
#             conclusions
#             -Around 20% of patients are smokers
#             -majority of patients do not smoke
#             -there are no missing values

# %%
df_insurance['smoker'].value_counts()
# Out:
# smoker
# No     1066
# Yes     274
# Name: count, dtype: int64

# %%
df_insurance['smoker'].value_counts()/len(df_insurance['smoker'])*100
# Out:
# smoker
# No     79.552239
# Yes    20.447761
# Name: count, dtype: float64

# %%
df_insurance['smoker'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['smoker'].value_counts().plot(kind = 'bar',linewidth=1,edgecolor='black',color=['aquamarine','lightcoral','steelblue','tomato'])
plt.xlabel("Smoke")
plt.ylabel("Number of patients")
plt.title("Smoking Data",fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
pie_colors = ['midnightblue','gray','olivedrab','orchid']
explode=[0.1,0]
df_insurance['smoker'].value_counts().plot(kind='pie',autopct= '%.2f%%',explode = explode,colors=pie_colors,shadow=True)
plt.legend()
plt.show()

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
#         REGION
#         conclusions
#         -southeast has majority of patients(around 33%)
#         -northeast has minority of patients(around 17%)
#         -there are 3 missing values

# %%
df_insurance['region'].value_counts()
# Out:
# region
# southeast    443
# northwest    349
# southwest    314
# northeast    231
# Name: count, dtype: int64

# %%
df_insurance['region'].isnull().sum()
# Out:
# np.int64(3)

# %%
df_insurance['region'].fillna('Missing')
# Out:
# 0       southeast
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1335    northwest
# 1336    northeast
# 1337    northwest
# 1338    southeast
# 1339    southeast
# Name: region, Length: 1340, dtype: object

# %%
df_insurance['region'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_insurance['region'].value_counts().plot(kind = 'bar',linewidth=1,edgecolor='black',color=['rosybrown','brown','steelblue','tomato'])
plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Number of patients across regions",fontdict={'fontname': 'comic sans ms','fontweight': 10,'color':'black'})
plt.show()

# %%
pie_colors = ['turquoise','salmon','olivedrab','orchid']
explode=[0.1,0,0,0]
df_insurance['region'].value_counts().plot(kind='pie',autopct= '%.2f%%',colors=pie_colors,explode=explode,shadow=True)
plt.legend()
plt.show()

# %% [markdown]
#         BIVARIATE ANALYSIS

# %%
df_insurance
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df_insurance[df_insurance['gender']=='male']['claim'].plot(kind='kde', label='male')
df_insurance[df_insurance['gender']=='female']['claim'].plot(kind='kde', label='female')
plt.xlabel('claim')
plt.legend()
plt.show()

# %%
sns.lmplot(x='age', y='claim', data=df_insurance,hue = 'gender')

# %%
sns.lmplot(x='bmi', y='claim', data=df_insurance)
plt.show()

# %%
sns.lmplot(x='bloodpressure', y='claim', data=df_insurance,hue = 'diabetic')
plt.show()

# %%
sns.lmplot(x='children', y='claim', data=df_insurance)
plt.show()
